# %%
# 모든 데이터를 array 형식으로 변경
import numpy as np
# 분석을 하기위한 표 객체
import pandas as pd
# 차트 시각화 패키지
import matplotlib.pyplot as plt
# 차트 통계용 시각화 패키지
import seaborn as sns

# 그래프의 모양 설정
plt.style.use('seaborn')
# 글자 크기 설정
# scale이랑 size랑 비슷
sns.set(font_scale = 2.5)

# 경고 메시지가 출력되지 않도록 설정
import warnings
warnings.filterwarnings('ignore')

# % 문자열을 inline (가로한줄)형식으로 // 문자열을 한줄로 표현
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
#train.csv 파일을 읽어서 df_train에 저장
# train 학습 / test 추론 
df_train = pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
# 각 컬럼의 개수, 평균, 표준편차, 최소값 등을 출력
# describe = 데이터프레임에서 가져온 내용을 간단한 통계로 정리
df_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
# df_train의 행이 개수 출력
len(df_train)
# Out:
# 891

# %%
# 각 컬럼의 널값의 수 조회
# 널 값 조회하는 이유 = 널은 분석을 방해한다
df_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
# 각 컬럼의 널 값의 비율 조회
# 각 컬럼의 널값의 수(df_train.isnull().sum()) / df_train 행의 개수 (len(df_frain))
df_train.isnull().sum() / len(df_train)
# Out:
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# Survived       0.000000
# dtype: float64

# %%
import missingno as msno
# msno.bar는 각 컬럼의 null 이 아닌 데이터의 비율을 그래프로 그려주는 패키지
msno.bar(df_train)

# %%
# 생존과 관련있는 컬럼 탐색

# %%
# Survived 컬럼에 저장된 값들의 빈도수 조회
# 0이 사망자 549명
# 1이 생존자 342명
df_train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# PClASS 컬럼과 생존률 관계

# %%
# 티켓 클래스의 빈도수 조회
df_train['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 각 줄이 생존자 Survived == 1인지 여부 조회
# 조건 만족 시 True 아니면 False 리턴
df_train['Survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22      True
# 23      True
# 24     False
# 25      True
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 861    False
# 862     True
# 863    False
# 864    False
# 865     True
# 866     True
# 867    False
# 868    False
# 869     True
# 870    False
# 871     True
# 872    False
# 873    False
# 874     True
# 875     True
# 876    False
# 877    False
# 878    False
# 879     True
# 880     True
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
# 생존자 Survived = 1인 줄의 데이터 조회
df_train[df_train['Survived'] == 1 ]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# 11            12       1                           Bonnell, Miss. Elizabeth
# 15            16       2                   Hewlett, Mrs. (Mary D Kingcome)
# 17            18       2                       Williams, Mr. Charles Eugene
# 19            20       3                            Masselmani, Mrs. Fatima
# 21            22       2                              Beesley, Mr. Lawrence
# ...

# %%
# 생존자 Survived = 1인 줄의 PClass 칸 조회
df_train[df_train['Survived'] == 1]["Pclass"]
# Out:
# 1      1
# 2      3
# 3      1
# 8      3
# 9      2
# 10     3
# 11     1
# 15     2
# 17     2
# 19     3
# 21     2
# 22     3
# 23     1
# 25     3
# 28     3
# 31     1
# 32     3
# 36     3
# 39     3
# 43     2
# 44     3
# 47     3
# 52     1
# 53     2
# 55     1
# 56     2
# 58     2
# 61     1
# 65     3
# 66     2
#       ..
# 809    1
# 820    1
# 821    3
# 823    3
# 827    2
# 828    3
# 829    1
# 830    3
# 831    2
# 835    1
# 838    3
# 839    1
# 842    1
# 849    1
# 853    1
# 855    3
# 856    1
# 857    1
# 858    3
# 862    1
# 865    2
# 866    2
# 869    3
# 871    1
# 874    2
# 875    3
# 879    1
# 880    2
# 887    1
# 889    1
# Name: Pclass, Length: 342, dtype: int64

# %%
# 생존자 Survived = 1인 줄의 Pclass 칸의 빈도 조회
df_train[df_train['Survived'] == 1]["Pclass"].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
# Pclass 칸과 Survived 칸을 교차해서 빈도수를 출력
# pd.crosstab(컬럼1, 컬럼2, margins = 합계를 출력하고자 하면 True 아니면 False)
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins = True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
# sex컬럼과 생존률 관계

# %%
# Sex와 Survived칸을 교차해서 빈도수를 출력
# pd.crosstab(컬럼1, 컬럼2, margin = True(합계 출력), False(출력X))
pd.crosstab(df_train['Sex'], df_train['Survived'], margins = True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
# 각 성별별로 Pclass 컬럼과 Survived 컬럼을 교차해서 그래프를 그림
# sns.factorplot(컬럼1, 컬럼2, hue = 범주에서 사용할 컬럼, data = 데이터프레임)
sns.factorplot('Pclass', 'Survived', hue = 'Sex', data = df_train)

# %%
# Age 컬럼과 생존률 관계

# %%
# df_train['Age'] 컬럼에서 [df_train['Survived'] == 1]인 행 대열
Survived_age = df_train['Age'][df_train['Survived'] ==1 ]
Survived_age
# Out:
# 1      38.00
# 2      26.00
# 3      35.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 15     55.00
# 17       NaN
# 19       NaN
# 21     34.00
# 22     15.00
# 23     28.00
# 25     38.00
# 28       NaN
# 31       NaN
# 32       NaN
# 36       NaN
# 39     14.00
# 43      3.00
# 44     19.00
# 47       NaN
# 52     49.00
# 53     29.00
# 55       NaN
# 56     21.00
# 58      5.00
# 61     38.00
# 65       NaN
# 66     29.00
#        ...
# 809    33.00
# 820    52.00
# 821    27.00
# 823    27.00
# 827     1.00
# 828      NaN
# 829    62.00
# 830    15.00
# 831     0.83
# 835    39.00
# 838    32.00
# 839      NaN
# 842    30.00
# 849      NaN
# 853    16.00
# 855    18.00
# 856    45.00
# 857    51.00
# 858    24.00
# 862    48.00
# 865    42.00
# 866    27.00
# 869     4.00
# 871    47.00
# 874    28.00
# 875    15.00
# 879    56.00
# 880    25.00
# 887    19.00
# 889    26.00
# Name: Age, Length: 342, dtype: float64

# %%
# df_train['Age'] 컬럼에서 [df_train['Survived'] == 0]인 행 대열
Dead_age = df_train['Age'][df_train['Survived'] == 0 ]
Dead_age
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 12     20.0
# 13     39.0
# 14     14.0
# 16      2.0
# 18     31.0
# 20     35.0
# 24      8.0
# 26      NaN
# 27     19.0
# 29      NaN
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 38     18.0
# 40     40.0
# 41     27.0
# 42      NaN
# 45      NaN
# 46      NaN
# 48      NaN
# 49     18.0
# 50      7.0
# 51     21.0
#        ...
# 844    17.0
# 845    42.0
# 846     NaN
# 847    35.0
# 848    28.0
# 850     4.0
# 851    74.0
# 852     9.0
# 854    44.0
# 859     NaN
# 860    41.0
# 861    21.0
# 863     NaN
# 864    24.0
# 867    31.0
# 868     NaN
# 870    26.0
# 872    33.0
# 873    47.0
# 876    20.0
# 877    19.0
# 878     NaN
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
# Age 컬럼에서 각 나이별 Survived_age와 Dead_age 비율을 그래프로 그림

# 그래프의 크기 설정 가로10 세로10
plt.figure(figsize=(10,10))
# 데이터.plot(kind = 'kde')는 비율을 그래프로 그려줌
Survived_age.plot(kind = 'kde')
Dead_age.plot(kind = 'kde')
# 범례를 설정
plt.legend(['Survived_age', 'Dead_age'])

# %%
# Embarked 컬럼과 생존률 관계

# %%
# Embarked 컬럼과 Survived 컬럼을 교차해서 빈도수 조회
# margins = True(합계 출력)
pd.crosstab(df_train['Embarked'], df_train['Survived'], margins = True)
# Out:
# Survived    0    1  All
# Embarked
# C          75   93  168
# Q          47   30   77
# S         427  217  644
# All       549  340  889

# %%
# Embarked 컬럼과 Pclass 컬럼을 교차해서 빈도수 조회
# margin = True (합계 출력)
pd.crosstab(df_train['Embarked'], df_train['Pclass'], margins = True)
# Out:
# Pclass      1    2    3  All
# Embarked
# C          85   17   66  168
# Q           2    3   72   77
# S         127  164  353  644
# All       214  184  491  889

# %%
# 상관관계파악
# Survived 컬럼과의 상관 관계를 출력
df_train.corr()["Survived"]
# Out:
# PassengerId   -0.005007
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Survived       1.000000
# Name: Survived, dtype: float64

# %%
# 컬럼의 기울임 정보 파악

# %%
# 각 컬럼의 기울어짐 정도 조회
df_train.skew()
# Out:
# PassengerId    0.000000
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# Survived       0.478523
# dtype: float64

# %%
# 가장 기울어진 컬럼 시각화
plt.hist(df_train["Fare"])
# distribution이 매우 비대칭 / 실제 예측 시에 좋지 못한 결과를 부를 수 있다.
# outlier의 영향을 줄이기 위해 Fare에 log를 취함
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <a list of 10 Patch objects>)

# %%
# Fare에 log(1+데이터)를 곱한 값을 리턴하는 np, log1p 호출
# Fare에 대입
df_train["Fare"] = np.log1p(df_train["Fare"])

# %%
plt.hist(df_train["Fare"])
# Out:
# (array([ 15.,   0.,   2., 350., 167., 182.,  85.,  59.,  28.,   3.]),
#  array([0.        , 0.62409174, 1.24818347, 1.87227521, 2.49636694,
#         3.12045868, 3.74455041, 4.36864215, 4.99273388, 5.61682562,
#         6.24091735]),
#  <a list of 10 Patch objects>)

# %%
# 전처리
# 계산을 통해서 새로운 컬럼을 추가 / 결측치가 있는 행에 값 대입

# %%
# (가족수)새로운 컬럼 추가

# %%
# sibSp 함께 탑승한 형제와 배우자의 수
# parch 함께 탑승한 부모, 아이의 수

# 배우자 수와 를부모 아이수 합해서 FamilySize컬럼 생성
# +1 아무도 없이 혼자 탑승했을 때
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1

# %%
# FamilySize와 Survived칸을 교차해서 빈도수를 출력
# pd.crosstab(컬럼1, 컬럼2, margins = 합계를 출력하고자 하면 True 아니면 False)
pd.crosstab(df_train['FamilySize'], df_train['Survived'], margins = True)
# Out:
# Survived      0    1  All
# FamilySize
# 1           374  163  537
# 2            72   89  161
# 3            43   59  102
# 4             8   21   29
# 5            12    3   15
# 6            19    3   22
# 7             8    4   12
# 8             6    0    6
# 11            7    0    7
# All         549  342  891

# %%
# Sir 컬럼 추가

# %%
# name 컬럼을 리스트로 변환해서 name_list에 대입
name_list = df_train["Name"].tolist()
name_list
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
# ...

# %%
import re
# 패턴찾기
# 다음 단어중 하나를 포함하는 문자열을 찾기 위한 객체 p 생성
p = re.compile("Mrs|Mr|Miss|Master|Don|Dr|Ms|Major|Mlle|Mme|Countess|Lady|Don|Countess")

# %%
for name in name_list:
    #p에 대입된 문자열과 name 일치하는 문자열을 리턴받아서 출력
    #일차하는 문자열이 name에 일치하는 문자열이 없으면 에러 발생
    print(p.search(name)[0])
# Out:
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Master
# Mrs
# Mrs
# Miss
# Miss
# Mr
# Mr
# Miss
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Don
# Mrs
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Miss
# Mrs
# Mrs
# Mr
# Miss
# Miss
# Mr
# Mr
# Dr
# Mr
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Master
# Mr
# Miss
# Mr
# Master
# Mr
# Master
# Mrs
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Master
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mr
# Miss
# Miss
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Miss
# Mr
# Master
# Mr
# Mr
# Miss
# Mr
# Dr
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# ---------------------------------------------------------------------------
# ...

# %%
for name in name_list:
    # 일치하는 문자열이 존재할 때는 p.search가 None이 아님
    if p.search(name) != None:
        print(p.search(name)[0]) # 문자열 출력
    else:
        print("Other") # 일치하는 문자열이 없을 때 Other 출력
# Out:
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Master
# Mrs
# Mrs
# Miss
# Miss
# Mr
# Mr
# Miss
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Don
# Mrs
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Miss
# Mrs
# Mrs
# Mr
# Miss
# Miss
# Mr
# Mr
# Dr
# Mr
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Master
# Mr
# Miss
# Mr
# Master
# Mr
# Master
# Mrs
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Master
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mr
# Miss
# Miss
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Miss
# Mr
# Master
# Mr
# Mr
# Miss
# Mr
# Dr
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Other
# Other
# Mrs
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Master
# Mr
# Mrs
# Mr
# Mr
# Master
# Master
# Mrs
# Mrs
# Mr
# Mr
# Mr
# ...

# %%
sir = []
for name in name_list:
    if p.search(name) != None:
        # 검색한 문자열이 'Countess','Lady','Mrs' 중 하나를 포함
        if p.search(name)[0] in ['Countess','Lady','Mrs']:
            # Mrs를 추가
            sir.append("Mrs")
        elif p.search(name)[0] in ['Mme','Ms','Mlle']: # 검색한 문자열이 Nme, Ms, Mlle 중 하나를 포함
            # Miss를 추가
            sir.append("Miss")
        elif p.search(name)[0] in ['Don','Dr','Major']: # 검색한 문자열이 'Don','Dr','Major' 중 하나를 포함
            # Mr를 추가
            sir.append("Mr")
        else:
            # 문자열을 추가
            sir.append(p.search(name)[0])
            
    else:
        # sir에 Other 추가
        sir.append("Other")

# %%
sir
# Out:
# ['Mr',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Master',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
# ...

# %%
# sir을 포함하는 데이터프레임 칸(Series) 생성
pd.Series(sir)
# Out:
# 0      Other
# 1        Mrs
# 2      Other
# 3        Mrs
# 4      Other
# 5      Other
# 6      Other
# 7      Other
# 8        Mrs
# 9        Mrs
# 10     Other
# 11     Other
# 12     Other
# 13     Other
# 14     Other
# 15       Mrs
# 16     Other
# 17     Other
# 18       Mrs
# 19       Mrs
# 20     Other
# 21     Other
# 22     Other
# 23     Other
# 24     Other
# 25       Mrs
# 26     Other
# 27     Other
# 28     Other
# 29     Other
#        ...
# 850    Other
# 851    Other
# 852      Mrs
# 853    Other
# 854    Other
# 855      Mrs
# 856    Other
# 857    Other
# 858    Other
# 859    Other
# 860    Other
# 861      Mrs
# 862    Other
# 863    Other
# 864      Mrs
# 865    Other
# 866    Other
# 867    Other
# 868    Other
# 869      Mrs
# 870      Mrs
# 871    Other
# 872    Other
# 873    Other
# 874    Other
# 875      Mrs
# 876    Other
# 877    Other
# 878    Other
# 879    Other
# Length: 880, dtype: object

# %%
# 빈도수를 조회
pd.Series(sir).value_counts()
# Out:
# Mr        530
# Miss      185
# Mrs       126
# Master     40
# Other      10
# dtype: int64

# %%
# sir을 포함하는 데이터프레임 칸 (Series) 생성
# df_train에 Sir이라는 칸이름으로 추가
df_train['Sir'] = pd.Series(sir)
df_train.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket      Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171  2.110213   NaN        S
# 1  female  38.0      1      0          PC 17599  4.280593   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282  2.188856   NaN        S
# 3  female  35.0      1      0            113803  3.990834  C123        S
# 4    male  35.0      0      0            373450  2.202765   NaN        S
#
#    Survived  FamilySize   Sir
# 0         0           2    Mr
# ...

# %%
# Sir과 Survived의 빈도수를 교차해서 출력
pd.crosstab(df_train['Sir'], df_train['Survived'], margins = True)
# Out:
# Survived    0    1  All
# Sir
# Master     17   23   40
# Miss       55  130  185
# Mr        442   88  530
# Mrs        26  100  126
# Other       9    1   10
# All       549  342  891

# %%
# 결측치 처리

# %%
#
