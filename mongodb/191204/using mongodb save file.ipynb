# %%
from pymongo import MongoClient
from gridfs import GridFS
from gridfs import GridFSBucket

# %%
from PIL import Image
from io import BytesIO

# %%
# mongodb에 python_test 데이터베이스에 접속
db = MongoClient().python_test

# %%
# python_test에 파일을 저장할 GridFS 객체 생성
fs = GridFS(db)

# %%
# GridFS에 저장된 데이터 정보 조회
db.fs.files.find()

# %%
# GridFS에 저장된 데이터 정보 조회
list(db.fs.files.find())
# Out:
# [{'_id': ObjectId('5de4cc930a09941695b7c55a'),
#   'filename': 'test.txt',
#   'md5': '0b97c2704cfb0e1892bb47a0b62bef96',
#   'chunkSize': 261120,
#   'length': 35,
#   'uploadDate': datetime.datetime(2019, 12, 2, 8, 34, 27, 720000)},
#  {'_id': ObjectId('5de70f8a42679fb1705eab7e'),
#   'filename': 'test.jpg',
#   'metadata': ['contentType'],
#   'chunkSize': 261120,
#   'md5': 'f7ffa1e1275757bffc2c917916af6b1d',
#   'length': 185721,
#   'uploadDate': datetime.datetime(2019, 12, 4, 1, 44, 42, 185000)}]

# %%
file_detail = db.fs.files.find()[1]

# %%
file_detail["filename"]
# Out:
# 'test.jpg'

# %%
file_detail["metadata"],["contentType"]
# Out:
# (['contentType'], ['contentType'])

# %%
f = fs.get_last_version(filename = "test.jpg")

# %%
data = f.read()
data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xed!\xa6Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x014\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02j~\x1c\x02x\x00\xc6\xea\xb0\x80\xec\x88\x98 \xec\x95\x84\xec\x9d\xb4\xec\x9c\xa0\xea\xb0\x80 2\xec\x9d\xbc \xec\x98\xa4\xed\x9b\x84 \xec\x84\x9c\xec\x9a\xb8 \xed\x99\x8d\xeb\x8c\x80 \xed\x94\x8c\xeb\x9e\x98\xea\xb7\xb8\xec\x8b\xad \xec\x8a\xa4\xed\x86\xa0\xec\x96\xb4\xec\x97\x90\xec\x84\x9c \xec\x97\xb4\xeb\xa6\xb0 \xed\x95\x9c \xec\x8a\xa4\xed\x8f\xac\xec\xb8\xa0 \xeb\xb8\x8c\xeb\x9e\x9c\xeb\x93\x9c\' \xed\x8c\xac \xeb\xb0\x8b \xec\x97\x85(Fan Meet UP)\' \xed\x96\x89\xec\x82\xac\xec\x97\x90 \xec\xb0\xb8\xec\x84\x9d\xed\x95\xb4 \xed\x95\x98\xed\x8a\xb8\xeb\xa5\xbc \xea\xb7\xb8\xeb\xa6\xac\xea\xb3\xa0 \xec\x9e\x88\xeb\x8b\xa4. 2018.11.2/\xeb\x89\xb4\xec\x8a\xa41\x1c\x02P\x00\x0bKwonHyonJin\x1c\x02\x05\x00\x1e\xec\x95\x84\xec\x9d\xb4\xec\x9c\xa0, \xec\x95\x99\xec\xa6\x9d\xeb\xa7\x9e\xec\x9d\x80 \xed\x95\x98\xed\x8a\xb8
# ...

# %%
# 문자로 나오는 것을 문자로 바꾸어주는 객체
from IPython.display import display

# %%
# data의 내용을 이미지로 변환해서 image에 저장
image = Image.open(BytesIO(data))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x764 at 0x2BC79B21C18>

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x764 at 0x2BC79B21C18>
