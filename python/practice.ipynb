# %%
import pandas as pd
df = pd.read_csv("C:/ai/workspace/data/cctv_in_seoul.csv")
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
df.shape
df
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
df.iloc[0:3,[0,2,4]]
# Out:
#    기관명  2013년도 이전  2015년
# 0  강남구       1292    584
# 1  강동구        379    155
# 2  강북구        369    138

# %%
df.count()
# Out:
# 기관명          25
# 소계           25
# 2013년도 이전    25
# 2014년        25
# 2015년        25
# 2016년        25
# dtype: int64

# %%
df = pd.read_excel("c:/ai/workspace/data/peoples.xlsx")
df.head()
# Out:
#     이름 성별  키[cm]  몸무게[Kg]
# 0  김성필  남  176.5     71.5
# 1  김민재  남  180.0     78.0
# 2  박은미  여  164.0     64.0
# 3  박성희  여  164.0     64.0
# 4  김이동  남  164.0     58.0

# %%
df.describe()
# Out:
#             키[cm]    몸무게[Kg]
# count   23.000000  23.000000
# mean   168.239130  65.021739
# std      6.633026   9.973235
# min    160.000000  50.000000
# 25%    163.500000  58.000000
# 50%    165.000000  62.000000
# 75%    174.500000  71.250000
# max    180.000000  89.000000

# %%
df
# Out:
#      이름 성별  키[cm]  몸무게[Kg]
# 0   김성필  남  176.5     71.5
# 1   김민재  남  180.0     78.0
# 2   박은미  여  164.0     64.0
# 3   박성희  여  164.0     64.0
# 4   김이동  남  164.0     58.0
# 5   최점심  여  164.0     58.0
# 6   양은희  여  160.0     50.0
# 7   오종갑  남  175.0     76.0
# 8   남중구  남  170.0     80.0
# 9   한주연  여  168.0     56.0
# 10  김원경  여  162.0     58.0
# 11  김영철  남  174.0     70.0
# 12  최도환  남  162.0     56.0
# 13  김상유  남  180.0     89.0
# 14  이재은  여  160.0     66.0
# 15  강진숙  여  164.0     59.0
# 16  조혜진  여  165.0     60.0
# 17  최희열  남  177.0     78.0
# 18  양영걸  남  178.0     71.0
# 19  박보경  남  163.0     54.0
# 20   낸시  여  163.0     56.0
# 21   조현  여  168.0     62.0
# 22   수지  여  168.0     61.0

# %%
df.drop('몸무게[Kg]', axis = 1, inplace = True)
df.head()
# Out:
#     이름 성별  키[cm]
# 0  김성필  남  176.5
# 1  김민재  남  180.0
# 2  박은미  여  164.0
# 3  박성희  여  164.0
# 4  김이동  남  164.0

# %%
import pandas as pd
persions_dict = {'Name' : ['김성필','양은희','이재은','신춘호'],
                'Gender' : ['남자','여자','여자','남자'],
                'Age' : [46, 24, 25, 33],
                'Job' : ['개발자','개발자','학생','개발자']
                }

# %%
df = pd.DataFrame(persions_dict)
df.head()
# Out:
#   Name Gender  Age  Job
# 0  김성필     남자   46  개발자
# 1  양은희     여자   24  개발자
# 2  이재은     여자   25   학생
# 3  신춘호     남자   33  개발자

# %%
df = pd.DataFrame(persions_dict, columns = ['Name','Job','Age','Gender'])
df.head()
# Out:
#   Name  Job  Age Gender
# 0  김성필  개발자   46     남자
# 1  양은희  개발자   24     여자
# 2  이재은   학생   25     여자
# 3  신춘호  개발자   33     남자

# %%
df.columns
# Out:
# Index(['Name', 'Job', 'Age', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.dtypes
# Out:
# Name      object
# Job       object
# Age        int64
# Gender    object
# dtype: object

# %%
df.values
# Out:
# array([['김성필', '개발자', 46, '남자'],
#        ['양은희', '개발자', 24, '여자'],
#        ['이재은', '학생', 25, '여자'],
#        ['신춘호', '개발자', 33, '남자']], dtype=object)

# %%
df.values[2]
# Out:
# array(['이재은', '학생', 25, '여자'], dtype=object)

# %%
persion = list(df.values[0])
persion
# Out:
# ['김성필', '개발자', 46, '남자']

# %%
df.Name
# Out:
# 0    김성필
# 1    양은희
# 2    이재은
# 3    신춘호
# Name: Name, dtype: object

# %%
df['Name']
# Out:
# 0    김성필
# 1    양은희
# 2    이재은
# 3    신춘호
# Name: Name, dtype: object

# %%
df
# Out:
#   Name  Job  Age Gender
# 0  김성필  개발자   46     남자
# 1  양은희  개발자   24     여자
# 2  이재은   학생   25     여자
# 3  신춘호  개발자   33     남자

# %%
df = pd.read_excel("c:/ai/workspace/data/peoples.xlsx")
df.head()
# Out:
#     이름 성별  키[cm]  몸무게[Kg]
# 0  김성필  남  176.5     71.5
# 1  김민재  남  180.0     78.0
# 2  박은미  여  164.0     64.0
# 3  박성희  여  164.0     64.0
# 4  김이동  남  164.0     58.0

# %%
newdf = df.sort_values(by='이름')
newdf.head()
# Out:
#      이름 성별  키[cm]  몸무게[Kg]
# 15  강진숙  여  164.0     59.0
# 1   김민재  남  180.0     78.0
# 13  김상유  남  180.0     89.0
# 0   김성필  남  176.5     71.5
# 11  김영철  남  174.0     70.0

# %%
newdf = df.sort_values(by='이름', ascending = False)
newdf.head()
# Out:
#      이름 성별  키[cm]  몸무게[Kg]
# 9   한주연  여  168.0     56.0
# 17  최희열  남  177.0     78.0
# 5   최점심  여  164.0     58.0
# 12  최도환  남  162.0     56.0
# 16  조혜진  여  165.0     60.0

# %%
import matplotlib.pyplot as plt
plt.stem( df['키[cm]'])
plt.show()

# %%
plt.stem(df['이름'], df['키[cm]'])
plt.show()

# %%
plt.stem(df['이름'][0:10], df['키[cm]'][0:10])
plt.show()

# %%
import matplotlib.font_manager as fm
f1 = fm.FontProperties(fname="c:/Windows/Fonts/HYKANB.ttf").get_name()
plt.rc('font', family = f1)

plt.stem(df['이름'][0:10], df['키[cm]'][0:10])
plt.show()

# %%
import pandas as pd
df = pd.read_csv("c:/ai/workspace/data/cctv_in_seoul.csv", encoding = 'UTF-8')
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613
